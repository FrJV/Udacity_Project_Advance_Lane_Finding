# %% [markdown]
# # Camera calibration

# %% [markdown]
# This Notebook is developed for the Udacity Project Advance Lane Finding. All steps and functions used are made based on those included in Lesson 6 from the Udacity course Self-driving car engineer.

# %% [markdown]
# ## 1- Import the necessary libraries

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# %matplotlib inline

# %% [markdown]
# ## 2- Create functions

# %% [markdown]
# 2.1 - Function to find and draw the corners of the chessboard

# %%
def find_corners_chessbooard(img,nx,ny,plot=1):
    '''img is the image in RGB
    nx and ny are the number of square coners (not counting external) in the chessboard in x and y direction
    ''' 
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)
    # If found, draw corners
    if ret and plot:
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (nx, ny), corners, ret)
        plt.imshow(img)
        #print(corners)
    return ret, corners

# %% [markdown]
# 2.3 - Function to create object points

# %%
def object_points(nx,ny):
    
    objp = np.zeros((nx*ny,3), np.float32)
    objp[:,:2] = np.mgrid[0:nx, 0:ny].T.reshape(-1,2)
    
    return objp

# %% [markdown]
# 2.3 - Function to undistort image

# %%
def cal_undistort(img, objpoints, imgpoints):
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img.shape[1:], None, None)
    undist = cv2.undistort(img, mtx, dist, None, mtx)
    return undist

# %% [markdown]
# 2.4 - Function to plot two images together

# %%
def plot_together(img1, img2):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
    f.tight_layout()
    ax1.imshow(img1)
    ax1.set_title('Image 1', fontsize=50)
    ax2.imshow(img2)
    ax2.set_title('Image 2', fontsize=50)
    plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)
    return None

# %% [markdown]
# ## 3 - Apply to provided images

# %%
image_list=glob.glob('camera_cal/calibration*.jpg')
nx=9
ny=6

# %% [markdown]
# 3.1 - Get image and object points lists

# %%
#Get object points (same for all images)
obj=object_points(nx,ny)

#Create the image points and object points list
img_points=[]
obj_points=[]

for fname in image_list:
    #Read image
    img=mpimg.imread(fname)
    plt.imshow(img)
    #Find image points
    ret, corners = find_corners_chessbooard(image,nx,ny,1)
    #print (ret)
    #Add points to list
    #if ret:
    #    img_points.append(corners)
    #    obj_points.append(objp)

# %%
print(obj_points)
# Out:
# []

# %% [markdown]
# 3.2 - Undistort images

# %%
print(img_points)
# Out:
# []

# %%
# Define example image to use and nx and ny
example_image='camera_cal/calibration2.jpg'

# %%
#Apply pipeline to example image
img = mpimg.imread(example_image)
objpoints=obj_points(nx,ny)
ret, imgpoints=find_corners_chessbooard(img,nx,ny)
print (ret)
cal_undistort(img, objpoints, imgpoints)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-83-0abedbd8646f> in <module>
#       3 objpoints=obj_points(nx,ny)
#       4 ret, imgpoints=find_corners_chessbooard(img,nx,ny)
# ----> 5 cal_undistort(img, objpoints, imgpoints)
#       6 print (ret)
#
# <ipython-input-68-ce129ed3de05> in cal_undistort(img, objpoints, imgpoints)
#       1 def cal_undistort(img, objpoints, imgpoints):
# ----> 2     ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img.shape[1:], None, None)
#       3     undist = cv2.undistort(img, mtx, dist, None, mtx)
#       4     return undist
#
# error: OpenCV(4.0.1) C:\ci\opencv-suite_1573470242804\work\modules\calib3d\src\calibration.cpp:3353: error: (-210:Unsupported format or combination of formats) objectPoints should contain vector of vectors of points of type Point3f in function 'cv::collectCalibrationData'

# %% [markdown]
# ## All images

# %%
A, b= find_corners_chessbooard(image,9,6)
print(A)
# Out:
# <img src="data:image/png;base64,..." width="598.9188983360875">
# True
