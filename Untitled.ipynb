# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import camera_cal_helper as cal
# %matplotlib notebook

# %%
image = mpimg.imread('output_images/straight_lines1_undistorted.jpg')
plt.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="639.9999780053498">

# %%
x_offlow=450
x_offhigh=75
top_img = cal.pers_transform(image, x_offlow, x_offhigh)
plt.imshow(top_img)
# Out:
# <img src="data:image/png;base64,..." width="639.9999780053498">
